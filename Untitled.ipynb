# %%
from datasets import load_dataset
from huggingface_hub import hf_hub_download, list_repo_files
import tarfile
import os

# Login using e.g. `huggingface-cli login` to access this dataset

repo_id = "rokmr/cricket-shot"

# List all files in the repository to identify correct paths
print("Listing files in repository:")
files_in_repo = list_repo_files(repo_id=repo_id, repo_type='dataset')
for f in files_in_repo:
    print(f)

# Based on the listing, the data is likely in a tar.gz file.
archive_filename = "cricketshot.tar.gz"
local_archive_path = hf_hub_download(repo_id=repo_id, filename=archive_filename, repo_type='dataset')
print(f"Downloaded archive to: {local_archive_path}")

# Extract the archive
extraction_path = "./cricketshot_data"
os.makedirs(extraction_path, exist_ok=True)

with tarfile.open(local_archive_path, "r:gz") as tar:
    tar.extractall(path=extraction_path, filter='data') # Added filter='data' to address DeprecationWarning

print(f"Extracted archive to: {extraction_path}")
print("Listing contents of extracted directory:")
for root, dirs, files in os.walk(extraction_path):
    for file in files:
        print(os.path.join(root, file))

# The following lines are commented out until correct filenames are identified
# filenames = {
#     "train": "cricket-shot-train.jsonl",
#     "test": "cricket-shot-test.jsonl",
#     "validation": "cricket-shot-val.jsonl",
# }

# # Download files locally
# local_data_files = {}
# for split, filename in filenames.items():
#     local_data_files[split] = hf_hub_download(repo_id=repo_id, filename=filename, repo_type='dataset')

# # Load the dataset from the locally downloaded files
# ds = load_dataset("json", data_files=local_data_files)
# print(ds)
# print(ds['train'].features)
# Out:
# Listing files in repository:
# .gitattributes
# README.md
# class_mapping.json
# cricketshot.tar.gz
# cricketshot.tar.gz:   0%|          | 0.00/2.89G [00:00<?, ?B/s]
# Downloaded archive to: /root/.cache/huggingface/hub/datasets--rokmr--cricket-shot/snapshots/d8ef77a54f1612a42a0ab49f732e49baf9c3cef8/cricketshot.tar.gz
# Extracted archive to: ./cricketshot_data
# Listing contents of extracted directory:
# ./cricketshot_data/._cricketshot
# ./cricketshot_data/cricketshot/._train
# ./cricketshot_data/cricketshot/.DS_Store
# ./cricketshot_data/cricketshot/._test
# ./cricketshot_data/cricketshot/._.DS_Store
# ./cricketshot_data/cricketshot/._val
# ./cricketshot_data/cricketshot/test/.DS_Store
# ./cricketshot_data/cricketshot/test/._defense
# ./cricketshot_data/cricketshot/test/._straight
# ./cricketshot_data/cricketshot/test/._sweep
# ./cricketshot_data/cricketshot/test/._pull
# ./cricketshot_data/cricketshot/test/._hook
# ./cricketshot_data/cricketshot/test/._cover
# ...

# %%
import json
import os
from huggingface_hub import hf_hub_download
from datasets import Dataset, Features, Value, ClassLabel, DatasetDict # Added imports for Dataset, Features, Value, ClassLabel, DatasetDict
import glob # Added import for glob

# The data is extracted to ./cricketshot_data/cricketshot/
base_data_path = "./cricketshot_data/cricketshot"
extraction_path = "./cricketshot_data" # Define extraction_path here for class_mapping

# Load the class mapping
# class_mapping.json is at the root of the HF repo, not inside the tar.gz or extraction path
repo_id = "rokmr/cricket-shot" # Ensure repo_id is defined
class_mapping_filename = "class_mapping.json"
class_mapping_path = hf_hub_download(repo_id=repo_id, filename=class_mapping_filename, repo_type='dataset')

with open(class_mapping_path, 'r') as f:
    class_mapping = json.load(f)

print("Class Mapping:", class_mapping)

# Prepare data files for load_dataset, pointing to the video directories
# The `datasets` library can automatically infer labels from folder names for image/audio/video datasets.
# We need to provide the paths to the split directories.

data_files = {
    "train": os.path.join(base_data_path, "train/*/*"), # Matches videos in shot type subfolders
    "test": os.path.join(base_data_path, "test/*/*"),
    "validation": os.path.join(base_data_path, "val/*/*"),
}

print("Data files structure for load_dataset:", data_files)

# Manually collect file paths and labels for each split
raw_datasets = {}
inverted_class_mapping = {v: int(k) for k, v in class_mapping.items()}

for split_name, glob_pattern in data_files.items():
    all_files = glob.glob(glob_pattern)
    examples = []
    for file_path in all_files:
        # Example path: ./cricketshot_data/cricketshot/train/cover/cover_001.avi
        # The label is the second to last component in the path
        parts = file_path.split(os.sep)
        label_name = parts[-2] # e.g., 'cover'

        label_id = inverted_class_mapping.get(label_name)

        if label_id is not None:
            examples.append({
                "video": file_path,
                "label": label_id # Store integer label
            })
        else:
            print(f"Warning: Could not find label for {label_name} in class_mapping for file: {file_path}")

    # Create Features object for the dataset
    features = Features({
        "video": Value("string"), # Store path as string
        "label": ClassLabel(names=list(inverted_class_mapping.keys())) # Use ClassLabel for classification
    })

    raw_datasets[split_name] = Dataset.from_list(examples, features=features)

# Combine into a DatasetDict
ds = DatasetDict(raw_datasets)

print(ds)
print(ds['train'].features)
print("First item in train split:", ds['train'][0])
# Out:
# class_mapping.json:   0%|          | 0.00/195 [00:00<?, ?B/s]
# Class Mapping: {'0': 'cover', '1': 'defense', '2': 'flick', '3': 'hook', '4': 'late_cut', '5': 'lofted', '6': 'pull', '7': 'square_cut', '8': 'straight', '9': 'sweep'}
# Data files structure for load_dataset: {'train': './cricketshot_data/cricketshot/train/*/*', 'test': './cricketshot_data/cricketshot/test/*/*', 'validation': './cricketshot_data/cricketshot/val/*/*'}
# DatasetDict({
#     train: Dataset({
#         features: ['video', 'label'],
#         num_rows: 1250
#     })
#     test: Dataset({
#         features: ['video', 'label'],
#         num_rows: 250
#     })
#     validation: Dataset({
#         features: ['video', 'label'],
#         num_rows: 250
#     })
# })
# {'video': Value('string'), 'label': ClassLabel(names=['cover', 'defense', 'flick', 'hook', 'late_cut', 'lofted', 'pull', 'square_cut', 'straight', 'sweep'])}
# ...

# %% [markdown]
# ## Load Model from Google Drive and Perform Inference (Self-Contained)

# %% [markdown]
# To log in to Hugging Face, you need an authentication token. You can generate one from your Hugging Face profile settings ([huggingface.co/settings/tokens](https://huggingface.co/settings/tokens)). Once you have your token, you can use `huggingface-cli login`.

# %%
# Using the huggingface-cli command to login:
# !huggingface-cli login

# Or, to log in programmatically using a token stored in Colab secrets (recommended for security):
from huggingface_hub import login
from google.colab import userdata

# Ensure your Hugging Face token is stored as a secret named 'HF_TOKEN' in Colab's secrets manager.
try:
    hf_token = userdata.get('HF_TOKEN')
    login(token=hf_token)
    print("Successfully logged in to Hugging Face Hub!")
except userdata.SecretNotFoundError:
    print("Hugging Face token not found in Colab secrets. Please add it as 'HF_TOKEN'.")
    print("You can also use '!huggingface-cli login' and paste your token manually.")
# Out:
# Successfully logged in to Hugging Face Hub!

# %%
# ==============================================================================
#  🏏 Cricket Shot Classifier — Google Colab Training Script
#  Model  : VideoMAE-base (fine-tuned on Kinetics-400)
#  Task   : 10-class cricket shot video classification
#  Dataset: rokmr/cricketshot (HuggingFace Hub)
#
#  HOW TO USE IN COLAB:
#  1. Upload this file to Colab  (or paste sections as cells)
#  2. Runtime → Change runtime type → GPU (T4 or A100)
#  3. Run cells top to bottom
# ==============================================================================


# ==============================================================================
# CELL 1 — Install Dependencies
# ==============================================================================
# Run this cell first. Restart runtime after installation if Colab prompts you.

import subprocess, sys

def install(pkg):
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", pkg])

PACKAGES = [
    "transformers>=4.40.0",
    "datasets",
    "accelerate",
    "evaluate",
    "scikit-learn",
    "decord",         # fast video decoder
    "av",             # fallback video decoder (PyAV)
    "matplotlib",
    "seaborn",
    "tqdm",
    "huggingface_hub",
]

print(" Installing dependencies...")
for pkg in PACKAGES:
    print(f"  Installing {pkg}...")
    install(pkg)

print("\n All dependencies installed. If prompted, restart the runtime and re-run from Cell 2.")


# ==============================================================================
# CELL 2 — GPU Check & Google Drive Mount
# ==============================================================================

import torch
import os

# --- GPU check ---
if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    gpu_mem  = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f" GPU detected : {gpu_name}  ({gpu_mem:.1f} GB VRAM)")
else:
    print("  No GPU detected. Switch to GPU runtime: Runtime → Change runtime type → GPU")

# --- Mount Google Drive (saves checkpoints so they survive session restarts) ---
MOUNT_DRIVE = True   # ← Set to False if you don't want Drive

if MOUNT_DRIVE:
    from google.colab import drive
    drive.mount("/content/drive")
    SAVE_DIR = "/content/drive/MyDrive/cricket_shot_classifier"
    os.makedirs(SAVE_DIR, exist_ok=True)
    print(f"\n Models will be saved to: {SAVE_DIR}")
else:
    SAVE_DIR = "/content/cricket_shot_classifier"
    os.makedirs(SAVE_DIR, exist_ok=True)
    print(f"\n Models will be saved to: {SAVE_DIR} (local — will be lost on session end)")


# ==============================================================================
# CELL 3 — HuggingFace Login
# ==============================================================================
# The rokmr/cricketshot dataset requires a HuggingFace account.
# Get your token from: https://huggingface.co/settings/tokens

from huggingface_hub import login

HF_TOKEN = ""   # ← PASTE YOUR TOKEN HERE  e.g. "hf_xxxxxxxxxxxx"
               #   OR leave empty to use interactive login below

if HF_TOKEN:
    login(token=HF_TOKEN, add_to_git_credential=False)
    print(" Logged in to HuggingFace with provided token.")
else:
    print(" No token provided — launching interactive login...")
    login()   # Opens a prompt asking for your token


# ==============================================================================
# CELL 4 — Configuration (edit these settings)
# ==============================================================================

CONFIG = {
    # ── Dataset ────────────────────────────────────────────────────────────────
    "dataset_name"   : "rokmr/cricketshot",
    "num_classes"    : 10,
    "class_names"    : [
        "cover", "defense", "flick", "hook", "late_cut",
        "lofted", "pull", "square_cut", "straight", "sweep"
    ],

    # ── Model ──────────────────────────────────────────────────────────────────
    #   Options (pick based on your GPU):
    #   "MCG-NJU/videomae-base-finetuned-kinetics"  ← recommended (T4 / V100)
    #   "MCG-NJU/videomae-large-finetuned-kinetics" ← best accuracy (A100 only)
    #   "facebook/timesformer-base-finetuned-k400"  ← alternative
    "model_checkpoint": "MCG-NJU/videomae-base-finetuned-kinetics",

    # ── Video sampling ─────────────────────────────────────────────────────────
    "num_frames"     : 16,     # frames sampled per clip
    "image_size"     : 224,    # VideoMAE native resolution

    # ── Training ───────────────────────────────────────────────────────────────
    "epochs"         : 10,     # ← REDUCED from 30
    "batch_size"     : 12,      # Keep this
    "grad_accum"     : 1,
    "learning_rate"  : 1e-4,   # Slightly higher learning rate
    "warmup_epochs"  : 0,      # ← REDUCED from 2 (save time)
    "weight_decay"   : 0.05,
    "fp16"           : True,
    "patience"       : 5,

    # ── Paths ──────────────────────────────────────────────────────────────────
    "output_dir"     : SAVE_DIR,
    "best_model_dir" : os.path.join(SAVE_DIR, "best_model"),
    "plots_dir"      : os.path.join(SAVE_DIR, "plots"),
}

os.makedirs(CONFIG["best_model_dir"], exist_ok=True)
os.makedirs(CONFIG["plots_dir"],      exist_ok=True)

print("⚙️  Configuration:")
for k, v in CONFIG.items():
    print(f"    {k:<20} = {v}")


# ==============================================================================
# CELL 5 — Load Dataset
# ==============================================================================

# from datasets import load_dataset # Already imported and dataset loaded in previous cells

print(f"\n📥 Using pre-loaded dataset...")
raw_dataset = ds # Use the dataset prepared in the previous cell
print(raw_dataset)

# Inspect one sample to understand the data format
sample = raw_dataset["train"][0]
print("\n🔍 Sample keys  :", list(sample.keys()))
print("   label       :", sample.get("label"))

# Find the video column name (varies by dataset)
VIDEO_COL  = "video" # Explicitly set, as we know it from our ds construction
LABEL_COL  = "label" # Explicitly set

# The original loop for VIDEO_COL and LABEL_COL is commented out since we explicitly know the names
# for col in ["video", "clip", "frames", "video_path", "file"]:
#     if col in sample:
#         VIDEO_COL = col
#         break

# if VIDEO_COL is None:
#     raise ValueError(
#         f"Could not find a video column. Available columns: {list(sample.keys())}\n"
#         "Set VIDEO_COL manually below."
#     )

print(f"   video column: {VIDEO_COL}")
print(f"   type        : {type(sample[VIDEO_COL])}")


# ==============================================================================
# CELL 6 — Video Preprocessing Utilities
# ==============================================================================

import numpy as np
import io, av, warnings

# Try importing decord (fast); fall back to PyAV
try:
    from decord import VideoReader, cpu
    DECORD_AVAILABLE = True
    print(" Using decord for video decoding.")
except ImportError:
    DECORD_AVAILABLE = False
    print("  decord not available — using PyAV (slower).")


def decode_video_decord(video_data) -> np.ndarray:
    """Decode video bytes/path with decord → (T, H, W, 3) uint8."""
    if isinstance(video_data, bytes):
        vr = VideoReader(io.BytesIO(video_data), ctx=cpu(0))
    elif isinstance(video_data, str):
        vr = VideoReader(video_data, ctx=cpu(0))
    elif hasattr(video_data, "path"):          # HF Video object
        vr = VideoReader(video_data.path, ctx=cpu(0))
    else:
        raise TypeError(f"Unsupported video type: {type(video_data)}")
    frames = vr.get_batch(range(len(vr))).asnumpy()  # (T, H, W, 3)
    return frames


def decode_video_av(video_data) -> np.ndarray:
    """Decode video bytes/path with PyAV → (T, H, W, 3) uint8."""
    if isinstance(video_data, (bytes, bytearray)):
        container = av.open(io.BytesIO(video_data))
    elif isinstance(video_data, str):
        container = av.open(video_data)
    elif hasattr(video_data, "path"):
        container = av.open(video_data.path)
    else:
        raise TypeError(f"Unsupported video type: {type(video_data)}")

    frames = []
    for frame in container.decode(video=0):
        frames.append(frame.to_ndarray(format="rgb24"))
    container.close()
    return np.stack(frames) if frames else np.zeros((1, 224, 224, 3), dtype=np.uint8)


def decode_video(video_data) -> np.ndarray:
    """Decode video using best available backend."""
    if DECORD_AVAILABLE:
        try:
            return decode_video_decord(video_data)
        except Exception:
            pass
    return decode_video_av(video_data)


def sample_frames_uniform(frames: np.ndarray, num_frames: int) -> np.ndarray:
    """Sample num_frames uniformly from a (T, H, W, 3) array."""
    T = len(frames)
    if T == 0:
        return np.zeros((num_frames, 224, 224, 3), dtype=np.uint8)
    indices = np.linspace(0, T - 1, num_frames, dtype=int)
    return frames[indices]  # (num_frames, H, W, 3)


# Quick test on one sample
print("\n🧪 Testing video decode on one training sample...")
test_frames_raw = decode_video(sample[VIDEO_COL])
test_frames     = sample_frames_uniform(test_frames_raw, CONFIG["num_frames"])
print(f"   Raw video shape  : {test_frames_raw.shape}")
print(f"   Sampled shape    : {test_frames.shape}  (should be {CONFIG['num_frames']} × H × W × 3)")


# ==============================================================================
# CELL 7 — Load Model & Processor
# ==============================================================================

from transformers import (
    VideoMAEImageProcessor,
    VideoMAEForVideoClassification,
    TimesformerForVideoClassification,
)
import os # Added import for os module

# Determine the path to load the model and processor from
# Check if a best model checkpoint exists to resume training
load_path = CONFIG["best_model_dir"]
if not os.path.exists(load_path) or not os.listdir(load_path):
    load_path = CONFIG["model_checkpoint"]
    print(f"\n📥 No existing checkpoint found. Loading processor from base: {load_path}")
else:
    print(f"\n📥 Checkpoint found. Loading processor from: {load_path} to resume training.")

processor = VideoMAEImageProcessor.from_pretrained(load_path)

# Determine the path to load the model from
# Check if a best model checkpoint exists to resume training
load_model_path = CONFIG["best_model_dir"]
if not os.path.exists(load_model_path) or not os.listdir(load_model_path):
    load_model_path = CONFIG["model_checkpoint"]
    print(f"📥 No existing checkpoint found. Loading model from base: {load_model_path}")
else:
    print(f"📥 Checkpoint found. Loading model from: {load_model_path} to resume training.")

id2label = {i: name for i, name in enumerate(CONFIG["class_names"])}
label2id = {name: i for i, name in id2label.items()}

model = VideoMAEForVideoClassification.from_pretrained(
    load_model_path, # Use load_model_path here
    num_labels=CONFIG["num_classes"],
    id2label=id2label,
    label2id=label2id,
    ignore_mismatched_sizes=True,   # replaces the 400-class head with 10-class
)

total_params     = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"\n📊 Model parameters:")
print(f"   Total     : {total_params / 1e6:.1f} M")
print(f"   Trainable : {trainable_params / 1e6:.1f} M")


# ==============================================================================
# CELL 8 — Dataset Preprocessing
# ==============================================================================

import torch
from torch.utils.data import Dataset, DataLoader

class CricketShotDataset(Dataset):
    """
    PyTorch Dataset for the rokmr/cricketshot HuggingFace dataset.
    Decodes videos, samples frames, applies VideoMAE processor.
    """

    def __init__(self, hf_dataset, processor, num_frames: int, image_size: int):
        self.data       = hf_dataset
        self.processor  = processor
        self.num_frames = num_frames
        self.image_size = image_size

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item  = self.data[idx]
        label = item[LABEL_COL]

        # ── Decode video → sample frames ──────────────────────────────────────
        try:
            raw_frames = decode_video(item[VIDEO_COL])
        except Exception as e:
            warnings.warn(f"Failed to decode video at index {idx}: {e}. Using blank frames.")
            raw_frames = np.zeros((self.num_frames, self.image_size, self.image_size, 3), dtype=np.uint8)

        frames = sample_frames_uniform(raw_frames, self.num_frames)  # (T, H, W, 3)

        # ── Apply VideoMAE processor ───────────────────────────────────────────
        # Processor expects list of PIL Images or list of (H,W,3) uint8 arrays
        frame_list = [frames[i] for i in range(self.num_frames)]
        inputs = self.processor(frame_list, return_tensors="pt")
        # pixel_values shape: (1, T, C, H, W) → squeeze batch dim
        pixel_values = inputs["pixel_values"].squeeze(0)  # (T, C, H, W)

        return {
            "pixel_values": pixel_values,
            "labels"      : torch.tensor(label, dtype=torch.long),
        }


# Build datasets
print("🔨 Building PyTorch datasets (this may take a moment)...")
train_split = raw_dataset.get("train",      raw_dataset.get("train"))
val_split   = raw_dataset.get("validation", raw_dataset.get("val"))
test_split  = raw_dataset.get("test")

train_dataset = CricketShotDataset(train_split, processor, CONFIG["num_frames"], CONFIG["image_size"])
val_dataset   = CricketShotDataset(val_split,   processor, CONFIG["num_frames"], CONFIG["image_size"])
test_dataset  = CricketShotDataset(test_split,  processor, CONFIG["num_frames"], CONFIG["image_size"]) if test_split else None

print(f"   Train samples : {len(train_dataset)}")
print(f"   Val samples   : {len(val_dataset)}")
print(f"   Test samples  : {len(test_dataset) if test_dataset else 'N/A'}")

# Quick shape check
sample_batch = train_dataset[0]
print(f"\n🔍 Sample pixel_values shape : {sample_batch['pixel_values'].shape}")
print(f"   Sample label              : {sample_batch['labels'].item()} ({id2label[sample_batch['labels'].item()]})")


# ==============================================================================
# CELL 9 — DataLoaders
# ==============================================================================

def collate_fn(batch):
    pixel_values = torch.stack([item["pixel_values"] for item in batch])
    labels       = torch.stack([item["labels"]       for item in batch])
    return {"pixel_values": pixel_values, "labels": labels}

NUM_WORKERS = 2   # Colab usually works fine with 2

train_loader = DataLoader(
    train_dataset,
    batch_size=CONFIG["batch_size"],
    shuffle=True,
    num_workers=NUM_WORKERS,
    pin_memory=True,
    collate_fn=collate_fn,
)

val_loader = DataLoader(
    val_dataset,
    batch_size=CONFIG["batch_size"],
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True,
    collate_fn=collate_fn,
)

test_loader = DataLoader(
    test_dataset,
    batch_size=CONFIG["batch_size"],
    shuffle=False,
    num_workers=NUM_WORKERS,
    pin_memory=True,
    collate_fn=collate_fn,
) if test_dataset else None

print(f"✅ DataLoaders ready.")
print(f"   Train batches : {len(train_loader)}")
print(f"   Val batches   : {len(val_loader)}")


# ==============================================================================
# CELL 10 — Training Setup
# ==============================================================================

from torch.optim import AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.cuda.amp import GradScaler, autocast

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model  = model.to(DEVICE)
print(f"🖥️  Training on: {DEVICE}")

optimizer = AdamW(
    model.parameters(),
    lr=CONFIG["learning_rate"],
    weight_decay=CONFIG["weight_decay"],
)

total_steps = len(train_loader) * CONFIG["epochs"] // CONFIG["grad_accum"]
warmup_steps = len(train_loader) * CONFIG["warmup_epochs"] // CONFIG["grad_accum"]

scheduler = CosineAnnealingLR(
    optimizer,
    T_max=total_steps - warmup_steps,
    eta_min=1e-6,
)

scaler = GradScaler(enabled=CONFIG["fp16"])


# Linear warmup helper
def get_warmup_factor(current_step: int, warmup_steps: int) -> float:
    if warmup_steps <= 0 or current_step >= warmup_steps:
        return 1.0
    return float(current_step) / float(max(1, warmup_steps))


# ==============================================================================
# CELL 11 — Training & Validation Loop
# ==============================================================================

import time
from tqdm.auto import tqdm

def compute_accuracy(logits: torch.Tensor, labels: torch.Tensor) -> float:
    preds = logits.argmax(dim=-1)
    return (preds == labels).float().mean().item()


def train_one_epoch(model, loader, optimizer, scheduler, scaler, epoch: int,
                    grad_accum: int, warmup_steps: int, global_step: list):
    model.train()
    total_loss, total_acc = 0.0, 0.0
    optimizer.zero_grad()

    pbar = tqdm(loader, desc=f"Epoch {epoch:02d} [Train]", leave=False)
    for step, batch in enumerate(pbar):
        pixel_values = batch["pixel_values"].to(DEVICE)
        labels       = batch["labels"].to(DEVICE)

        with autocast(enabled=CONFIG["fp16"]):
            outputs = model(pixel_values=pixel_values, labels=labels)
            loss    = outputs.loss / grad_accum

        scaler.scale(loss).backward()

        if (step + 1) % grad_accum == 0:
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

            # Warmup LR override
            global_step[0] += 1
            if global_step[0] < warmup_steps:
                wf = get_warmup_factor(global_step[0], warmup_steps)
                for pg in optimizer.param_groups:
                    pg["lr"] = CONFIG["learning_rate"] * wf
            else:
                scheduler.step()

        total_loss += outputs.loss.item()
        total_acc  += compute_accuracy(outputs.logits, labels)
        pbar.set_postfix(loss=f"{outputs.loss.item():.4f}")

    n = len(loader)
    return total_loss / n, total_acc / n


@torch.no_grad()
def validate(model, loader, split_name="Val"):
    model.eval()
    total_loss, total_acc = 0.0, 0.0

    pbar = tqdm(loader, desc=f"          [{split_name}] ", leave=False)
    for batch in pbar:
        pixel_values = batch["pixel_values"].to(DEVICE)
        labels       = batch["labels"].to(DEVICE)

        with autocast(enabled=CONFIG["fp16"]):
            outputs = model(pixel_values=pixel_values, labels=labels)

        total_loss += outputs.loss.item()
        total_acc  += compute_accuracy(outputs.logits, labels)

    n = len(loader)
    return total_loss / n, total_acc / n


# ── Training loop ──────────────────────────────────────────────────────────────

history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}
best_val_acc     = 0.0
patience_counter = 0
global_step      = [0]

print("\n" + "=" * 65)
print(f"  🚀  Starting Training  |  {CONFIG['epochs']} epochs  |  Device: {DEVICE}")
print("=" * 65)
print(f"  {'Epoch':>5}  {'Train Loss':>10}  {'Train Acc':>9}  {'Val Loss':>8}  {'Val Acc':>7}")
print("-" * 65)

for epoch in range(1, CONFIG["epochs"] + 1):
    t0 = time.time()

    train_loss, train_acc = train_one_epoch(
        model, train_loader, optimizer, scheduler, scaler,
        epoch, CONFIG["grad_accum"], warmup_steps, global_step
    )

    val_loss, val_acc = validate(model, val_loader)
    elapsed          = time.time() - t0

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss)
    history["val_acc"].append(val_acc)

    # Best model checkpoint
    improved = val_acc > best_val_acc
    if improved:
        best_val_acc = val_acc
        patience_counter = 0
        model.save_pretrained(CONFIG["best_model_dir"])
        processor.save_pretrained(CONFIG["best_model_dir"])
        flag = "⭐ best"
    else:
        patience_counter += 1
        flag = ""

    print(f"  {epoch:>5}  {train_loss:>10.4f}  {train_acc:>8.1%}  "
          f"{val_loss:>8.4f}  {val_acc:>6.1%}  {elapsed:>5.1f}s  {flag}")

    # Early stopping
    if patience_counter >= CONFIG["patience"]:
        print(f"\n⏹️  Early stopping at epoch {epoch} (no improvement for {CONFIG['patience']} epochs).")
        break

print("=" * 65)
print(f"✅ Training complete! Best val accuracy: {best_val_acc:.1%}")
print(f"   Best model saved to: {CONFIG['best_model_dir']}")


# ==============================================================================
# CELL 12 — Plot Training Curves
# ==============================================================================

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(14, 5))
fig.suptitle("Cricket Shot Classifier — Training Curves", fontsize=14, fontweight="bold")

gs = gridspec.GridSpec(1, 2, figure=fig)

# Loss
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(history["train_loss"], label="Train Loss", lw=2, color="#4C8BF5")
ax1.plot(history["val_loss"],   label="Val Loss",   lw=2, color="#F56C4C", linestyle="--")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Cross-Entropy Loss")
ax1.set_title("Loss")
ax1.legend()
ax1.grid(alpha=0.3)

# Accuracy
ax2 = fig.add_subplot(gs[0, 1])
ax2.plot([a * 100 for a in history["train_acc"]], label="Train Acc", lw=2, color="#4C8BF5")
ax2.plot([a * 100 for a in history["val_acc"]],   label="Val Acc",   lw=2, color="#F56C4C", linestyle="--")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Accuracy (%)")
ax2.set_title("Accuracy")
ax2.legend()
ax2.grid(alpha=0.3)
ax2.set_ylim(0, 100)

plt.tight_layout()
curve_path = os.path.join(CONFIG["plots_dir"], "training_curves.png")
plt.savefig(curve_path, dpi=150, bbox_inches="tight")
plt.show()
print(f"📊 Saved training curves → {curve_path}")


# ==============================================================================
# CELL 13 — Full Evaluation on Test Set
# ==============================================================================

import sklearn.metrics as skm
import seaborn as sns

print("\n🔍 Loading best model for test evaluation...")
best_model = VideoMAEForVideoClassification.from_pretrained(CONFIG["best_model_dir"]).to(DEVICE)
best_model.eval()

if test_loader:
    all_preds, all_labels = [], []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Evaluating on test set"):
            pixel_values = batch["pixel_values"].to(DEVICE)
            labels       = batch["labels"].to(DEVICE)

            with autocast(enabled=CONFIG["fp16"]):
                outputs = best_model(pixel_values=pixel_values)

            preds = outputs.logits.argmax(dim=-1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Metrics
    acc    = skm.accuracy_score(all_labels, all_preds)
    f1     = skm.f1_score(all_labels, all_preds, average="macro")
    report = skm.classification_report(
        all_labels, all_preds,
        target_names=CONFIG["class_names"]
    )

    print("\n" + "=" * 55)
    print(f"  📊  Test Set Results")
    print("=" * 55)
    print(f"  Accuracy (top-1) : {acc:.1%}")
    print(f"  F1 (macro)       : {f1:.4f}")
    print("-" * 55)
    print(report)

    # Confusion matrix
    cm = skm.confusion_matrix(all_labels, all_preds)
    fig, ax = plt.subplots(figsize=(12, 10))
    sns.heatmap(
        cm, annot=True, fmt="d", cmap="Blues",
        xticklabels=CONFIG["class_names"],
        yticklabels=CONFIG["class_names"],
        ax=ax
    )
    ax.set_title("Confusion Matrix — Cricket Shot Classifier", fontsize=14, fontweight="bold")
    ax.set_xlabel("Predicted", fontsize=12)
    ax.set_ylabel("True",      fontsize=12)
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()

    cm_path = os.path.join(CONFIG["plots_dir"], "confusion_matrix.png")
    plt.savefig(cm_path, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"📊 Confusion matrix saved → {cm_path}")

else:
    print("⚠️  No test split available — skipping test evaluation.")


# ==============================================================================
# CELL 14 — Single-Video Inference (Test with your own clip)
# ==============================================================================
if 'id2label' not in globals():
    id2label = {i: label for i, label in enumerate(CONFIG["class_names"])}
    label2id = {label: i for i, label in enumerate(CONFIG["class_names"])}
def predict_shot(video_path_or_bytes, model, processor, num_frames: int = 16) -> dict:
    """
    Predict cricket shot from a video file.

    Args:
        video_path_or_bytes: path to .mp4 file OR raw bytes
        model              : fine-tuned VideoMAEForVideoClassification
        processor          : VideoMAEImageProcessor
        num_frames         : frames to sample (must match training)

    Returns:
        dict with 'predicted_class', 'confidence', 'top3'
    """
    model.eval()

    # Decode + sample frames
    raw_frames = decode_video(video_path_or_bytes)
    frames     = sample_frames_uniform(raw_frames, num_frames)
    frame_list = [frames[i] for i in range(num_frames)]

    # Preprocess
    inputs       = processor(frame_list, return_tensors="pt")
    pixel_values = inputs["pixel_values"].to(DEVICE)

    # Inference
    with torch.no_grad():
        with autocast(enabled=CONFIG["fp16"]):
            outputs = model(pixel_values=pixel_values)

    probs     = torch.softmax(outputs.logits, dim=-1)[0].cpu().numpy()
    top3_idx  = probs.argsort()[::-1][:3]

    return {
        "predicted_class": id2label[int(probs.argmax())],
        "confidence"     : float(probs.max()),
        "top3"           : [
            {"shot": id2label[int(i)], "prob": float(probs[i])}
            for i in top3_idx
        ],
    }


# ── Example usage (upload a video to Colab first) ─────────────────────────────
#
# from google.colab import files
# uploaded = files.upload()
# video_path = list(uploaded.keys())[0]
#
# result = predict_shot(video_path, best_model, processor)
# print(f"\n🏏 Predicted Shot : {result['predicted_class'].upper()}")
# print(f"   Confidence     : {result['confidence']:.1%}")
# print("\n   Top-3 predictions:")
# for rank, item in enumerate(result["top3"], 1):
#     bar = "█" * int(item["prob"] * 30)
#     print(f"   {rank}. {item['shot']:<12} {item['prob']:>5.1%}  {bar}")

print("✅ Inference function ready. Uncomment the example above to test a video.")


# ==============================================================================
# CELL 15 — Download Results (saves model + plots as ZIP to local machine)
# ==============================================================================

import zipfile

if not MOUNT_DRIVE:
    # If Drive is not mounted, zip everything for manual download
    zip_path = "/content/cricket_shot_classifier_results.zip"
    with zipfile.ZipFile(zip_path, "w", zipfile.ZIP_DEFLATED) as zf:
        for root, dirs, files in os.walk(CONFIG["output_dir"]):
            for file in files:
                fp = os.path.join(root, file)
                zf.write(fp, os.path.relpath(fp, "/content"))

    from google.colab import files
    files.download(zip_path)
    print(f"📦 Downloaded results ZIP: {zip_path}")
else:
    print(f"📁 All results already saved to Google Drive: {CONFIG['output_dir']}")
    print(f"   ├── best_model/    (model weights + processor)")
    print(f"   └── plots/         (training curves + confusion matrix)")


# ==============================================================================
# DONE
# ==============================================================================
print("""
╔══════════════════════════════════════════════════════╗
║      🏏  Cricket Shot Classifier — Training Done!   ║
╠══════════════════════════════════════════════════════╣
║  Model   : VideoMAE-base fine-tuned on your data    ║
║  Weights : best_model/ (saved to Drive or zipped)   ║
║  Plots   : training_curves.png + confusion_matrix   ║
╚══════════════════════════════════════════════════════╝
""")
# Out:
# 📦 Installing dependencies...
#   Installing transformers>=4.40.0...
#   Installing datasets...
#   Installing accelerate...
#   Installing evaluate...
#   Installing scikit-learn...
#   Installing decord...
#   Installing av...
#   Installing matplotlib...
#   Installing seaborn...
#   Installing tqdm...
#   Installing huggingface_hub...
#
# ✅ All dependencies installed. If prompted, restart the runtime and re-run from Cell 2.
# ✅ GPU detected : Tesla T4  (15.6 GB VRAM)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 📁 Models will be saved to: /content/drive/MyDrive/cricket_shot_classifier
# 🔑 No token provided — launching interactive login...
# ⚙️  Configuration:
#     dataset_name         = rokmr/cricketshot
#     num_classes          = 10
#     class_names          = ['cover', 'defense', 'flick', 'hook', 'late_cut', 'lofted', 'pull', 'square_cut', 'straight', 'sweep']
# ...

# %%
import sklearn.metrics as skm
import seaborn as sns

print("\n🔍 Loading best model for test evaluation...")
best_model = VideoMAEForVideoClassification.from_pretrained(CONFIG["best_model_dir"]).to(DEVICE)
best_model.eval()

if test_loader:
    all_preds, all_labels = [], []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Evaluating on test set"):
            pixel_values = batch["pixel_values"].to(DEVICE)
            labels       = batch["labels"].to(DEVICE)

            with autocast(enabled=CONFIG["fp16"]):
                outputs = best_model(pixel_values=pixel_values)

            preds = outputs.logits.argmax(dim=-1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Metrics
    acc    = skm.accuracy_score(all_labels, all_preds)
    f1     = skm.f1_score(all_labels, all_preds, average="macro")
    report = skm.classification_report(
        all_labels, all_preds,
        target_names=CONFIG["class_names"]
    )

    print("\n" + "=" * 55)
    print(f"  📊  Test Set Results")
    print("=" * 55)
    print(f"  Accuracy (top-1) : {acc:.1%}")
    print(f"  F1 (macro)       : {f1:.4f}")
    print("-" * 55)
    print(report)

    # Confusion matrix
    cm = skm.confusion_matrix(all_labels, all_preds)
    fig, ax = plt.subplots(figsize=(12, 10))
    sns.heatmap(
        cm, annot=True, fmt="d", cmap="Blues",
        xticklabels=CONFIG["class_names"],
        yticklabels=CONFIG["class_names"],
        ax=ax
    )
    ax.set_title("Confusion Matrix — Cricket Shot Classifier", fontsize=14, fontweight="bold")
    ax.set_xlabel("Predicted", fontsize=12)
    ax.set_ylabel("True",      fontsize=12)
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()

    cm_path = os.path.join(CONFIG["plots_dir"], "confusion_matrix.png")
    plt.savefig(cm_path, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"📊 Confusion matrix saved → {cm_path}")

else:
    print("⚠️  No test split available — skipping test evaluation.")
# Out:
# 🔍 Loading best model for test evaluation...
# ...
# Evaluating on test set:   0%|          | 0/21 [00:00<?, ?it/s]
# /tmp/ipykernel_66960/3795995502.py:16: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=CONFIG["fp16"]):
# ...
#   📊  Test Set Results
# ...
#   Accuracy (top-1) : 88.8%
#   F1 (macro)       : 0.8887
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#        cover       0.88      0.84      0.86        25
#      defense       0.96      1.00      0.98        25
#        flick       0.91      0.80      0.85        25
#         hook       0.92      0.88      0.90        25
#     late_cut       0.92      0.92      0.92        25
#       lofted       0.74      1.00      0.85        25
#         pull       0.81      0.84      0.82        25
#   square_cut       0.83      0.80      0.82        25
# ...

# %%
# !pip

# %% [markdown]
# ## Live Key Point Extraction with MediaPipe

# %%
import torch
import os
import numpy as np
import io, av, warnings
from transformers import VideoMAEImageProcessor, VideoMAEForVideoClassification

# --- Configuration (re-defining essential parts for this self-contained cell) ---
# Assuming Google Drive is mounted to /content/drive
SAVE_DIR = "/content/drive/MyDrive/cricket_shot_classifier"

CONFIG = {
    "num_classes"    : 10,
    "class_names"    : [
        "cover", "defense", "flick", "hook", "late_cut",
        "lofted", "pull", "square_cut", "straight", "sweep"
    ],
    "num_frames"     : 16,
    "image_size"     : 224,
    "best_model_dir" : os.path.join(SAVE_DIR, "best_model"),
    "fp16"           : True,
}

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

id2label = {i: name for i, name in enumerate(CONFIG["class_names"])}
label2id = {name: i for i, name in id2label.items()}

# --- Video Decoding Utilities (copied from Cell 6) ---
try:
    from decord import VideoReader, cpu
    DECORD_AVAILABLE = True
    print("✅ Using decord for video decoding.")
except ImportError:
    DECORD_AVAILABLE = False
    print("⚠️  decord not available — using PyAV (slower). If you get errors, consider restarting runtime and ensuring decord is installed.")

def decode_video_decord(video_data) -> np.ndarray:
    """Decode video bytes/path with decord → (T, H, W, 3) uint8."""
    if isinstance(video_data, bytes):
        vr = VideoReader(io.BytesIO(video_data), ctx=cpu(0))
    elif isinstance(video_data, str):
        vr = VideoReader(video_data, ctx=cpu(0))
    elif hasattr(video_data, "path"): # HF Video object
        vr = VideoReader(video_data.path, ctx=cpu(0))
    else:
        raise TypeError(f"Unsupported video type: {type(video_data)}")
    frames = vr.get_batch(range(len(vr))).asnumpy() # (T, H, W, 3)
    return frames

def decode_video_av(video_data) -> np.ndarray:
    """Decode video bytes/path with PyAV → (T, H, W, 3) uint8."""
    if isinstance(video_data, (bytes, bytearray)):
        container = av.open(io.BytesIO(video_data))
    elif isinstance(video_data, str):
        container = av.open(video_data)
    elif hasattr(video_data, "path"):
        container = av.open(video_data.path)
    else:
        raise TypeError(f"Unsupported video type: {type(video_data)}")

    frames = []
    for frame in container.decode(video=0):
        frames.append(frame.to_ndarray(format="rgb24"))
    container.close()
    return np.stack(frames) if frames else np.zeros((1, CONFIG["image_size"], CONFIG["image_size"], 3), dtype=np.uint8)

def decode_video(video_data) -> np.ndarray:
    """Decode video using best available backend."""
    if DECORD_AVAILABLE:
        try:
            return decode_video_decord(video_data)
        except Exception:
            pass
    return decode_video_av(video_data)

def sample_frames_uniform(frames: np.ndarray, num_frames: int) -> np.ndarray:
    """Sample num_frames uniformly from a (T, H, W, 3) array."""
    T = len(frames)
    if T == 0:
        return np.zeros((num_frames, CONFIG["image_size"], CONFIG["image_size"], 3), dtype=np.uint8)
    indices = np.linspace(0, T - 1, num_frames, dtype=int)
    return frames[indices]  # (num_frames, H, W, 3)


# --- Load Model and Processor ---
print(f"\n📥 Loading processor from: {CONFIG['best_model_dir']}")
processor = VideoMAEImageProcessor.from_pretrained(
    CONFIG["best_model_dir"],
    local_files_only=True, # Explicitly tell it to only look locally
    token=None # Ensure no token is used, further indicating local-only
)

print(f"📥 Loading model from: {CONFIG['best_model_dir']}")
best_model = VideoMAEForVideoClassification.from_pretrained(
    CONFIG["best_model_dir"],
    num_labels=CONFIG["num_classes"],
    id2label=id2label,
    label2id=label2id,
    ignore_mismatched_sizes=True,
    local_files_only=True, # Explicitly tell it to only look locally
    token=None # Ensure no token is used
).to(DEVICE)
best_model.eval()

print(f"✅ Model and processor loaded on {DEVICE}.")


# --- Prediction Function (copied from Cell 14) ---
def predict_shot(video_path_or_bytes, model, processor, num_frames: int = 16) -> dict:
    """
    Predict cricket shot from a video file.

    Args:
        video_path_or_bytes: path to .mp4 file OR raw bytes
        model              : fine-tuned VideoMAEForVideoClassification
        processor          : VideoMAEImageProcessor
        num_frames         : frames to sample (must match training)

    Returns:
        dict with 'predicted_class', 'confidence', 'top3'
    """
    model.eval()

    # Decode + sample frames
    raw_frames = decode_video(video_path_or_bytes)
    frames     = sample_frames_uniform(raw_frames, num_frames)
    frame_list = [frames[i] for i in range(num_frames)]

    # Preprocess
    inputs       = processor(frame_list, return_tensors="pt")
    pixel_values = inputs["pixel_values"].to(DEVICE)

    # Inference
    with torch.no_grad():
        with torch.cuda.amp.autocast(enabled=CONFIG["fp16"]):
            outputs = model(pixel_values=pixel_values)

    probs     = torch.softmax(outputs.logits, dim=-1)[0].cpu().numpy()
    top3_idx  = probs.argsort()[::-1][:3]

    return {
        "predicted_class": id2label[int(probs.argmax())],
        "confidence"     : float(probs.max()),
        "top3"           : [
            {"shot": id2label[int(i)], "prob": float(probs[i])}
            for i in top3_idx
        ],
    }

# --- Example Usage (uncomment to run) ---
# from google.colab import files
# uploaded = files.upload()
# video_path = list(uploaded.keys())[0]

# if 'video_path' in locals():
#     result = predict_shot(video_path, best_model, processor, num_frames=CONFIG["num_frames"])
#     print(f"\n🏏 Predicted Shot : {result['predicted_class'].upper()}")
#     print(f"   Confidence     : {result['confidence']:.1%}")
#     print("\n   Top-3 predictions:")
#     for rank, item in enumerate(result["top3"], 1):
#         bar = "█" * int(item["prob"] * 30)
#         print(f"   {rank}. {item['shot']:<12} {item['prob']:>5.1%}  {bar}")
# else:
#     print("\n⚠️  No video uploaded. To test, uncomment the example usage and upload a video file.")

print("\nInference setup complete. Uncomment the example usage section above to upload a video and test the model.")
# Out:
# ✅ Using decord for video decoding.
#
# 📥 Loading processor from: /content/drive/MyDrive/cricket_shot_classifier/best_model
# 📥 Loading model from: /content/drive/MyDrive/cricket_shot_classifier/best_model
# Loading weights:   0%|          | 0/186 [00:00<?, ?it/s]
# ✅ Model and processor loaded on cpu.
#
# Inference setup complete. Uncomment the example usage section above to upload a video and test the model.

# %%
# !pip install av decord

# %%
# !pip uninstall -y mediapipe opencv-python opencv-contrib-python opencv-python-headless
# !pip install --upgrade pip
# !pip install mediapipe==0.10.33 opencv-python-headless==4.13.0.92 --force-reinstall
# Out:
# WARNING: Skipping mediapipe as it is not installed.
# WARNING: Skipping opencv-python as it is not installed.
# WARNING: Skipping opencv-contrib-python as it is not installed.
# WARNING: Skipping opencv-python-headless as it is not installed.
# ...
#   Using cached mediapipe-0.10.33-py3-none-manylinux_2_28_x86_64.whl.metadata (9.8 kB)
# ...
#   Using cached opencv_python_headless-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# ...
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached sounddevice-0.5.5-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# ...
#   Using cached opencv_contrib_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# ...
#   Using cached matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# ...

# %% [markdown]
# ### Live Key Point Extraction with MediaPipe
#
# **Note**: After running the `!pip install` cell above, you must **restart your Colab runtime** (`Runtime > Restart runtime`) and then execute this cell.
#
# This code will open your webcam feed (if available and permissions are granted) and display real-time pose estimation using MediaPipe. Press 'q' to quit the live feed.

# %%
import mediapipe
import os

print(f"MediaPipe version: {mediapipe.__version__}")
print(f"MediaPipe path: {mediapipe.__path__}")

# Attempt to import solutions directly
try:
    from mediapipe import solutions
    print("✅ Successfully imported mediapipe.solutions.")
    print(f"Solutions path: {solutions.__path__}")
except ImportError as e:
    print(f"❌ Failed to import mediapipe.solutions: {e}")
    print("This indicates a problem with the mediapipe installation or environment.")

# Optionally, list contents of the solutions directory if found
if 'solutions' in locals() and solutions.__path__ and os.path.isdir(solutions.__path__[0]):
    print("Contents of mediapipe.solutions package:")
    print(os.listdir(solutions.__path__[0]))
# Out:
# MediaPipe version: 0.10.33
# MediaPipe path: ['/usr/local/lib/python3.12/dist-packages/mediapipe']
# ❌ Failed to import mediapipe.solutions: cannot import name 'solutions' from 'mediapipe' (/usr/local/lib/python3.12/dist-packages/mediapipe/__init__.py)
# This indicates a problem with the mediapipe installation or environment.

# %%
import os
import mediapipe

# Get the mediapipe installation path
mediapipe_path = mediapipe.__path__[0]
print(f"Listing contents of: {mediapipe_path}")

# List all files and directories in the mediapipe installation path
for item in os.listdir(mediapipe_path):
    print(f" - {item}")

# Also check if a 'python' subdirectory exists and list its contents
python_path = os.path.join(mediapipe_path, 'python')
if os.path.isdir(python_path):
    print(f"\nListing contents of mediapipe/python: {python_path}")
    for item in os.listdir(python_path):
        print(f" - {item}")

    solutions_path = os.path.join(python_path, 'solutions')
    if os.path.isdir(solutions_path):
        print(f"\nListing contents of mediapipe/python/solutions: {solutions_path}")
        for item in os.listdir(solutions_path):
            print(f" - {item}")
# Out:
# Listing contents of: /usr/local/lib/python3.12/dist-packages/mediapipe
#  - __pycache__
#  - __init__.py
#  - tasks
#  - modules

# %%
import cv2
import mediapipe
import numpy as np
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import os # Added os import for path checking

# --- MediaPipe Setup (using the new Task API) ---

# Step 1: Create a PoseLandmarker object.
# Download the pose_landmarker_lite.task model if you haven't already
# You might need to adjust the path or download it dynamically.

POSE_LANDMARKER_MODEL_PATH = 'pose_landmarker_lite.task'

# Download the model if it doesn't exist (only for Colab environment setup)
if not os.path.exists(POSE_LANDMARKER_MODEL_PATH):
    print(f"Downloading MediaPipe Pose Landmarker model to {POSE_LANDMARKER_MODEL_PATH}...")
    try:
        # Using curl to download the model from Google's hosted storage
        # !curl -o {POSE_LANDMARKER_MODEL_PATH} https://storage.googleapis.com/mediapipe-models/pose_landmarker/pose_landmarker_lite/float16/1/pose_landmarker_lite.task
        print("Download complete.")
    except Exception as e:
        print(f"Error downloading model: {e}")
        print("Please manually download 'pose_landmarker_lite.task' and place it in the same directory as this notebook.")


# Configure PoseLandmarkerOptions
base_options = python.BaseOptions(model_asset_path=POSE_LANDMARKER_MODEL_PATH)
options = vision.PoseLandmarkerOptions(base_options=base_options,
                                       output_segmentation_masks=False)

# Create PoseLandmarker
landmarker = vision.PoseLandmarker.create_from_options(options)
print("✅ MediaPipe PoseLandmarker initialized.")

# --- Video Capture and Processing ---

# Open webcam (0 for default webcam, change if you have multiple)
# In Colab, you might need to use a different approach for live webcam feed, or upload a video file.
# For a local environment, cv2.VideoCapture(0) works.
# For Colab, you generally need to capture frames using JavaScript. This example assumes a local setup or a pre-recorded video.

# To test with a video file in Colab:
from google.colab import files
print("Please upload a video file for processing.")
uploaded = files.upload()
if uploaded:
    video_path = list(uploaded.keys())[0]
    cap = cv2.VideoCapture(video_path)

    # cap = cv2.VideoCapture(0) # This is commented out, as it was attempting to open webcam.

    if not cap.isOpened():
        print("Error: Could not open video file. Please ensure it's a valid video format.")
        exit() # Exit if the uploaded video itself cannot be opened

    print("Starting video processing. Press 'q' to quit.")

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("End of video or failed to grab frame. Exiting...")
            break

        # Flip the frame horizontally for a mirror effect (optional)
        frame = cv2.flip(frame, 1)

        # Convert the frame to MediaPipe Image format
        # MediaPipe expects RGB, so convert BGR from OpenCV
        mp_image = mediapipe.Image(image_format=mediapipe.ImageFormat.SRGB, data=frame)

        # Perform pose landmark detection
        detection_result = landmarker.detect(mp_image)

        # Draw the pose landmarks on the frame
        if detection_result.pose_landmarks:
            for landmark_list in detection_result.pose_landmarks:
                for landmark in landmark_list:
                    x = int(landmark.x * frame.shape[1])
                    y = int(landmark.y * frame.shape[0])
                    cv2.circle(frame, (x, y), 5, (0, 255, 0), -1) # Green circle for landmarks

                # Optional: Draw connections (you might need to define connections manually or use a utility if available)
                # For example, to draw connections for basic body parts:
                # connections = mediapipe.solutions.pose.POSE_CONNECTIONS # This is from the old API, would need a custom implementation
                # For simplicity, drawing individual landmarks for now.

        # Display the frame - In Colab, cv2.imshow does not work. We need to convert it to an image for display.
        # For real-time display in Colab, consider using IPython.display or a video writer to save the output.
        # For this example, we'll just process frames.
        # To see the output, you would typically save frames to a video or display static images.

        # Example of saving a single frame for inspection (uncomment if needed)
        # if cap.get(cv2.CAP_PROP_POS_FRAMES) == 10: # Save 10th frame
        #    cv2.imwrite('frame_with_landmarks.jpg', frame)

        # Break the loop on 'q' key press (will not work in Colab output directly)
        # if cv2.waitKey(5) & 0xFF == ord('q'):
        #     break

    # Release resources
    cap.release()
    cv2.destroyAllWindows()
    print("Video processing stopped.")
else:
    print("No video file uploaded. Exiting.")
    exit()
# Out:
# ✅ MediaPipe PoseLandmarker initialized.
# Please upload a video file for processing.
#      <input type="file" id="files-600ae2c6-8b13-4f81-afb0-6be1eae7248a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-600ae2c6-8b13-4f81-afb0-6be1eae7248a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# !python --version
# !pip list | grep mediapipe
# !pip list | grep opencv
# Out:
# Python 3.12.13
# mediapipe                                0.10.33
# opencv-contrib-python                    4.13.0.92
# opencv-python                            4.13.0.92
# opencv-python-headless                   4.13.0.92

# %% [markdown]
# ### Live Webcam Feed with MediaPipe (Colab-specific)
#
# This section enables live webcam processing directly in Google Colab. It captures frames from your browser's webcam, sends them to the Python backend for MediaPipe processing, and then displays the annotated frames back in the notebook output.
#
# **Important:**
# 1. You will be prompted to grant webcam access in your browser.
# 2. The frame rate might be lower than a native application due to the browser-Python communication.
# 3. To stop the webcam feed, click the 'STOP' button or interrupt the kernel (Runtime -> Interrupt execution).

# %%
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io

def js_to_image(js_reply):
  """
  Converts a JavaScript object containing image data to an OpenCV image.
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

def image_to_js(img):
  """
  Converts an OpenCV image (BGR) to JavaScript byte string (base64).
  """
  # convert OpenCV image to JPEG data
  img_bytes = cv2.imencode('.jpg', img)[1].tobytes()
  # encode to base64
  jpg_as_text = b64encode(img_bytes).decode('ascii')
  return jpg_as_text

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.n      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      return new Promise((resolve) => {
        capture.onclick = () => {
          const canvas = document.createElement('canvas');
          canvas.width = video.videoWidth;
          canvas.height = video.videoHeight;
          canvas.getContext('2d').drawImage(video, 0, 0);
          stream.getVideoTracks()[0].stop();
          div.remove();
          resolve(canvas.toDataURL('image/jpeg', quality));
        };
      });
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  img = js_to_image(data)
  cv2.imwrite(filename, img)

  return filename

def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;

    var pendingResolve = null;
    var shutdown = false;

    function startAndStop() {
      if (!div) {
        div = document.createElement('div');
        document.body.appendChild(div);
      }
      video = document.createElement('video');
      video.style.display = 'block';
      div.appendChild(video);

      stream = await navigator.mediaDevices.getUserMedia({video: true});
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for the video to be playable
      await new Promise((resolve) => video.onplaying = resolve);

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = video.videoWidth;
      captureCanvas.height = video.videoHeight;
      imgElement = document.createElement('img');
      imgElement.src = 'https://colab.research.google.com/img/camera.gif';
      div.appendChild(imgElement);
      labelElement = document.createElement('span');
      div.appendChild(labelElement);

      // Add a STOP button
      const stopButton = document.createElement('button');
      stopButton.textContent = 'STOP';
      div.appendChild(stopButton);
      stopButton.onclick = function() {
        shutdown = true;
        if (stream) {
          stream.getVideoTracks()[0].stop();
        }
        if (pendingResolve) {
          resolve(null);
        }
        div.remove();
        div = null;
        video = null;
        stream = null;
        captureCanvas = null;
        imgElement = null;
        labelElement = null;
        stopButton.remove();
      };

      function sendFrame() {
        if (shutdown) {
          return;
        }
        captureCanvas.getContext('2d').drawImage(video, 0, 0);
        var data = captureCanvas.toDataURL('image/jpeg', 0.8);
        google.colab.kernel.invokeFunction('js_send_frame', [data]);
        if (!shutdown) {
          requestAnimationFrame(sendFrame);
        }
      }

      sendFrame();
    }

    startAndStop();
    ''')
  display(js)

# Register a callback to handle frames from JavaScript
from google.colab import output # Corrected import

def _receive_frame(frame_data):
    global current_frame_data
    current_frame_data = frame_data

output.register_callback('js_send_frame', _receive_frame) # Corrected callback registration

# Global variable to store the latest frame data
current_frame_data = None

print("Ready to stream from webcam. Run the next cell to start processing.")
# Out:
# Ready to stream from webcam. Run the next cell to start processing.

# %%
# !pip install kernel

# %%
from mediapipe.tasks.python import vision # Ensure vision is imported

# Start the video stream (this will display a video feed and a STOP button)
video_stream()

print("Starting MediaPipe Pose Detection. Click 'STOP' to end.")

try:
    while True:
        if current_frame_data:
            # Convert base64 image data to OpenCV image
            frame = js_to_image(current_frame_data)

            # Convert frame to MediaPipe Image format
            mp_image = mediapipe.Image(image_format=mediapipe.ImageFormat.SRGB, data=frame)

            # Perform pose landmark detection
            detection_result = landmarker.detect(mp_image)

            # Draw the pose landmarks on the frame
            if detection_result.pose_landmarks:
                for landmark_list in detection_result.pose_landmarks:
                    for landmark in landmark_list:
                        x = int(landmark.x * frame.shape[1])
                        y = int(landmark.y * frame.shape[0])
                        cv2.circle(frame, (x, y), 5, (0, 255, 0), -1) # Green circle for landmarks

            # Convert OpenCV image back to JavaScript format for display
            processed_image_js = image_to_js(frame)

            # Display the processed frame in the output area (or update existing one)
            display(Image(data=processed_image_js), display_id='live_output')

            # Clear current_frame_data to wait for the next frame
            current_frame_data = None

except KeyboardInterrupt:
    print("Stream interrupted by user.")
except Exception as e:
    print(f"An error occurred: {e}")

finally:
    print("Live stream processing finished.")
# Out:
# Starting MediaPipe Pose Detection. Click 'STOP' to end.
# Stream interrupted by user.
# Live stream processing finished.
